# %% [markdown]
# # Statistiche e grafici delle risoluzioni<br>Cubo di Rubik 4x4x4

# %% [markdown]
# <img src="../immagini/cubo_4x4x4.jpg" width="400" height="400">

# %%
# Caricamento dati delle risoluzioni dal database
import modulo_rubik
CUBO = "4x4x4"
df = modulo_rubik.caricamento_dati(cubo=CUBO)

# %%
# DataFrame contenente i dati
df
# Out:
#     Data completa  Anno       Mese  Giorno  Secondi    Tempo   Cubo
# 0      2025-01-18  2025    Gennaio      18   294.18  4:54.18  4x4x4
# 1      2025-01-18  2025    Gennaio      18   227.47  3:47.47  4x4x4
# 2      2025-01-18  2025    Gennaio      18   218.12  3:38.12  4x4x4
# 3      2025-01-19  2025    Gennaio      19   246.79  4:06.79  4x4x4
# 4      2025-01-19  2025    Gennaio      19   373.76  6:13.76  4x4x4
# ..            ...   ...        ...     ...      ...      ...    ...
# 135    2026-09-02  2026  Settembre       2   218.75  3:38.75  4x4x4
# 136    2026-09-02  2026  Settembre       2   163.77  2:43.77  4x4x4
# 137    2026-09-03  2026  Settembre       3   159.41  2:39.41  4x4x4
# 138    2026-09-03  2026  Settembre       3   186.45  3:06.45  4x4x4
# 139    2026-09-03  2026  Settembre       3   163.64  2:43.64  4x4x4
#
# [140 rows x 7 columns]

# %% [markdown]
# # 📈Analisi dei tempi di risoluzione

# %%
# Grafico con la concentrazione dei dati sui tempi delle risoluzioni
modulo_rubik.grafico_concentrazione_dati(df=df)

# %%
modulo_rubik.calcolo_correlazione(df=df)
# Out:
# Coefficiente di correlazione -0.653923405739303
# Questo valore indica che maggiore è il numero di risoluzioni, minore è il tempo di risoluzione

# %% [markdown]
# ## 🥇Record attuale

# %%
# Record
modulo_rubik.stampa_record(cubo=CUBO)
# Out:
# Il record attuale è di 2 minuti e 26.08 secondi

# %% [markdown]
# ## Classifica delle 10 risoluzioni più veloci 🥇🥈🥉...

# %%
modulo_rubik.classifica_migliori_soluzioni(df_cubo=df)
# Out:
# Classifica delle 10 risoluzioni più veloci
#
#   Data completa  Anno       Mese  Giorno  Secondi    Tempo  Differenza secondi
# 0    2026-04-17  2026     Aprile      17   146.08  2:26.08                0.00
# 1    2026-04-17  2026     Aprile      17   148.08  2:28.08                2.00
# 2    2026-04-19  2026     Aprile      19   153.11  2:33.11                5.03
# 3    2026-05-20  2026     Maggio      20   154.06  2:34.06                0.95
# 4    2026-08-17  2026     Agosto      17   155.92  2:35.92                1.86
# 5    2026-04-11  2026     Aprile      11   156.89  2:36.89                0.97
# 6    2026-09-03  2026  Settembre       3   159.41  2:39.41                2.52
# 7    2026-09-03  2026  Settembre       3   163.64  2:43.64                4.23
# 8    2026-09-02  2026  Settembre       2   163.77  2:43.77                0.13
# 9    2026-08-15  2026     Agosto      15   164.98  2:44.98                1.21

# %% [markdown]
# ## 📊 Tempo minimo, medio e massimo delle risoluzioni

# %%
# Tempo massimo medio e minimo delle risoluzioni
modulo_rubik.stampa_record_media_massimo(df_cubo=df, cubo=CUBO)
# Out:
# Tempo minimo medio e massimo delle risoluzioni:
# - Tempo minimo 2:26.08
#  - Tempo medio 3:43.3
#  - Tempo massimo 6:57.31

# %%
# Grafico tempo massimo medio e minimo delle risoluzioni
modulo_rubik.grafico_record_media_massimo(df_cubo=df)

# %% [markdown]
# ## 🗓️ Analisi dei tempi di risoluzione mensili e annuali

# %%
# Record mensili del 2025
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2025)
# Out:
# Record stabiliti ogni mese
#
#            Secondi    Tempo
# Mese
# Gennaio     218.12  3:38.12
# Febbraio    223.11  3:43.11
# Maggio      241.70  4:01.70
# Luglio      242.52  4:02.52
# Agosto      232.52  3:52.52
# Settembre   210.86  3:30.86
# Ottobre     236.82  3:56.82
# Novembre    225.30  3:45.30

# %%
# Grafico dei record mensili del 2025
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2025)

# %%
# Record mensili del 2026
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2026)
# Out:
# Record stabiliti ogni mese
#
#            Secondi    Tempo
# Mese
# Gennaio     185.99  3:05.99
# Febbraio    191.52  3:11.52
# Marzo       179.03  2:59.03
# Aprile      146.08  2:26.08
# Maggio      154.06  2:34.06
# Giugno      170.13  2:50.13
# Luglio      188.34  3:08.34
# Agosto      155.92  2:35.92
# Settembre   159.41  2:39.41

# %%
# Grafico dei record mensili del 2026
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2026)

# %%
# Record mensili di tutti gli anni
modulo_rubik.calcola_record_mensili_tutti_anni(df_cubo=df)
# Out:
# Anno         2025    2026
# Mese
# Gennaio    218.12  185.99
# Febbraio   223.11  191.52
# Marzo        0.00  179.03
# Aprile       0.00  146.08
# Maggio     241.70  154.06
# Giugno       0.00  170.13
# Luglio     242.52  188.34
# Agosto     232.52  155.92
# Settembre  210.86  159.41
# Ottobre    236.82    0.00
# Novembre   225.30    0.00
# Dicembre     0.00    0.00

# %%
# Grafico dei record mensili di tutti gli anni
modulo_rubik.grafico_record_mensili_tutti_anni(df_cubo=df)

# %%
# Tempi medi mensili delle risoluzioni del 2025
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2025)
# Out:
# Tempi medi delle risoluzioni mensili
#
#            Secondi    Tempo
# Mese
# Gennaio     271.68  4:31.68
# Febbraio    310.90  5:10.90
# Maggio      244.26  4:04.26
# Luglio      310.07  5:10.07
# Agosto      250.83  4:10.83
# Settembre   241.45  4:01.45
# Ottobre     278.69  4:38.69
# Novembre    251.54  4:11.54

# %%
# Grafico dei tempi medi mensili delle risoluzioni del 2025
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2025)

# %%
# Tempi medi mensili delle risoluzioni del 2026
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Tempi medi delle risoluzioni mensili
#
#            Secondi    Tempo
# Mese
# Gennaio     221.91  3:41.91
# Febbraio    231.29  3:51.29
# Marzo       208.66  3:28.66
# Aprile      181.03  3:01.03
# Maggio      208.63  3:28.63
# Giugno      200.73  3:20.73
# Luglio      200.03  3:20.03
# Agosto      174.98  2:54.98
# Settembre   182.36  3:02.36

# %%
# Grafico dei tempi medi mensili delle risoluzioni 2026
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
# Medie mensili di tutti gli anni
modulo_rubik.calcola_medie_mensili_tutti_anni(df_cubo=df)
# Out:
# Anno         2025    2026
# Mese
# Gennaio    271.68  221.91
# Febbraio   310.90  231.29
# Marzo        0.00  208.66
# Aprile       0.00  181.03
# Maggio     244.26  208.63
# Giugno       0.00  200.73
# Luglio     310.07  200.03
# Agosto     250.83  174.98
# Settembre  241.45  182.36
# Ottobre    278.69    0.00
# Novembre   251.54    0.00
# Dicembre     0.00    0.00

# %%
# Grafico delle mensili di tutti gli anni
modulo_rubik.grafico_medie_mensili_tutti_anni(df_cubo=df)

# %%
# Tempi record delle risoluzioni annuali
modulo_rubik.record_risoluzioni_annuali(df_cubo=df)
# Out:
# Tempi record stabiliti ogni anno
#
#       Secondi    Tempo
# Anno
# 2025   210.86  3:30.86
# 2026   146.08  2:26.08

# %%
# Grafico dei tempi record delle risoluzioni annuali
modulo_rubik.grafico_record_annuali(df_cubo=df)

# %%
# Tempi medi delle risoluzioni annuali
modulo_rubik.medie_risoluzioni_annuali(df_cubo=df)
# Out:
# Tempi medi delle risoluzioni annuali
#
#       Secondi    Tempo
# Anno
# 2025   267.25  4:27.25
# 2026   201.10  3:21.10

# %%
# Grafico dei tempi medi delle risoluzioni annuali
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %% [markdown]
# ## 🔢 Analisi del numero di risoluzioni mensili e annuali

# %%
# Numero di risoluzioni mensili del 2025
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2025)
# Out:
# Numero di risoluzioni mensili del 2025
#
# Mese
# Agosto       11
# Novembre      9
# Gennaio       7
# Luglio        6
# Settembre     5
# Febbraio      4
# Ottobre       3
# Maggio        2
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2025
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2025)

# %%
# Numero di risoluzioni mensili del 2026
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Numero di risoluzioni mensili del 2026
#
# Mese
# Aprile       17
# Maggio       16
# Marzo        16
# Febbraio     10
# Agosto        8
# Gennaio       7
# Giugno        7
# Settembre     7
# Luglio        5
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2026
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)

# %%
# Numero risoluzioni mensili di tutti gli anni
modulo_rubik.calcola_num_risoluz_mensile_tutti_anni(df_cubo=df)
# Out:
# Anno       2025  2026
# Mese
# Gennaio       7     7
# Febbraio      4    10
# Marzo         0    16
# Aprile        0    17
# Maggio        2    16
# Giugno        0     7
# Luglio        6     5
# Agosto       11     8
# Settembre     5     7
# Ottobre       3     0
# Novembre      9     0
# Dicembre      0     0

# %%
# Grafico del numero risoluzioni mensili di tutti gli anni
modulo_rubik.grafico_risoluz_mensile_tutti_anni(df_cubo=df)

# %%
# Numero di risoluzioni annuali
modulo_rubik.numero_risoluzioni_annuali(df_cubo=df)
# Out:
# Numero di risoluzioni annuali
#
# Anno
# 2025    47
# 2026    93
# Name: count, dtype: int64

# %%
# Grafico con il numero di risoluzioni annuali
modulo_rubik.grafico_risoluz_annuali(df_cubo=df)

# %% [markdown]
# ## 📈Analisi dei tempi di risoluzione

# %% [markdown]
# ### 💯 Ultime risoluzioni (fino ad un massimo di 100)

# %%
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=100)
# Out:
# Tempo medio: 3:24.95

# %% [markdown]
# ## 📈Analisi dei tempi delle risoluzioni più recenti

# %% [markdown]
# ### 🔟 Ultime 10 risoluzioni

# %%
df.tail(10)
# Out:
#     Data completa  Anno       Mese  Giorno  Secondi    Tempo   Cubo
# 130    2026-08-22  2026     Agosto      22   185.17  3:05.17  4x4x4
# 131    2026-08-22  2026     Agosto      22   177.43  2:57.43  4x4x4
# 132    2026-08-17  2026     Agosto      17   155.92  2:35.92  4x4x4
# 133    2026-09-02  2026  Settembre       2   174.48  2:54.48  4x4x4
# 134    2026-09-02  2026  Settembre       2   209.99  3:29.99  4x4x4
# 135    2026-09-02  2026  Settembre       2   218.75  3:38.75  4x4x4
# 136    2026-09-02  2026  Settembre       2   163.77  2:43.77  4x4x4
# 137    2026-09-03  2026  Settembre       3   159.41  2:39.41  4x4x4
# 138    2026-09-03  2026  Settembre       3   186.45  3:06.45  4x4x4
# 139    2026-09-03  2026  Settembre       3   163.64  2:43.64  4x4x4

# %%
# Grafico delle ultime 10 risoluzioni in base alla data e ai secondi impiegati
modulo_rubik.grafico_risoluzioni_recenti(df_cubo=df)

# %%
# Grafico delle ultime 10 risoluzioni in base al numero della risoluzione e ai secondi impiegati
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=10)
# Out:
# Tempo medio: 2:59.5
