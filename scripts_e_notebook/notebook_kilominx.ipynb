# %% [markdown]
# # Statistiche e grafici delle risoluzioni del<br>Kilominx

# %% [markdown]
# <img src="../immagini/kilominx.jpg" width="400" height="450">

# %%
# Caricamento dati delle risoluzioni dal database
import modulo_rubik
CUBO = "kilominx"
df = modulo_rubik.caricamento_dati(cubo=CUBO)

# %%
# DataFrame contenente i dati
df
# Out:
#    Data completa  Anno      Mese  Giorno  Secondi     Tempo      Cubo
# 0     2026-02-17  2026  Febbraio      17   746.26  12:26.26  kilominx
# 1     2026-02-17  2026  Febbraio      17   640.63  10:40.63  kilominx
# 2     2026-02-17  2026  Febbraio      17   442.95   7:22.95  kilominx
# 3     2026-02-18  2026  Febbraio      18   542.82   9:02.82  kilominx
# 4     2026-02-18  2026  Febbraio      18   396.86   6:36.86  kilominx
# ..           ...   ...       ...     ...      ...       ...       ...
# 58    2026-06-14  2026    Giugno      14   278.47   4:38.47  kilominx
# 59    2026-06-14  2026    Giugno      14   150.72   2:30.72  kilominx
# 60    2026-06-14  2026    Giugno      14   185.84   3:05.84  kilominx
# 61    2026-08-22  2026    Agosto      22   191.17   3:11.17  kilominx
# 62    2026-08-22  2026    Agosto      22   204.44   3:24.44  kilominx
#
# [63 rows x 7 columns]

# %% [markdown]
# # 📈Analisi dei tempi di risoluzione

# %%
# Grafico con la concentrazione dei dati sui tempi delle risoluzioni
modulo_rubik.grafico_concentrazione_dati(df=df)

# %%
modulo_rubik.calcolo_correlazione(df=df)
# Out:
# Coefficiente di correlazione -0.7005245155838844
# Questo valore indica che maggiore è il numero di risoluzioni, minore è il tempo di risoluzione

# %% [markdown]
# ## 🥇Record attuale

# %%
# Record
modulo_rubik.stampa_record(cubo=CUBO)
# Out:
# Il record attuale è di 2 minuti e 30.72 secondi

# %% [markdown]
# ## Classifica delle 10 risoluzioni più veloci 🥇🥈🥉...

# %%
modulo_rubik.classifica_migliori_soluzioni(df_cubo=df)
# Out:
# Classifica delle 10 risoluzioni più veloci
#
#   Data completa  Anno    Mese  Giorno  Secondi    Tempo  Differenza secondi
# 0    2026-06-14  2026  Giugno      14   150.72  2:30.72                0.00
# 1    2026-04-14  2026  Aprile      14   166.06  2:46.06               15.34
# 2    2026-04-06  2026  Aprile       6   168.89  2:48.89                2.83
# 3    2026-03-28  2026   Marzo      28   169.19  2:49.19                0.30
# 4    2026-03-03  2026   Marzo       3   169.51  2:49.51                0.32
# 5    2026-06-14  2026  Giugno      14   185.84  3:05.84               16.33
# 6    2026-03-03  2026   Marzo       3   189.89  3:09.89                4.05
# 7    2026-08-22  2026  Agosto      22   191.17  3:11.17                1.28
# 8    2026-05-08  2026  Maggio       8   195.33  3:15.33                4.16
# 9    2026-03-03  2026   Marzo       3   196.57  3:16.57                1.24

# %% [markdown]
# ## 📊 Tempo minimo, medio e massimo delle risoluzioni

# %%
# Tempo massimo medio e minimo delle risoluzioni
modulo_rubik.stampa_record_media_massimo(df_cubo=df, cubo=CUBO)
# Out:
# Tempo minimo medio e massimo delle risoluzioni:
# - Tempo minimo 2:30.72
#  - Tempo medio 5:0.2
#  - Tempo massimo 12:26.26

# %%
# Grafico tempo massimo medio e minimo delle risoluzioni
modulo_rubik.grafico_record_media_massimo(df_cubo=df)

# %% [markdown]
# ## 🗓️ Analisi dei tempi di risoluzione mensili e annuali

# %%
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2026)
# Out:
# Record stabiliti ogni mese
#
#           Secondi    Tempo
# Mese
# Febbraio   232.15  3:52.15
# Marzo      169.19  2:49.19
# Aprile     166.06  2:46.06
# Maggio     195.33  3:15.33
# Giugno     150.72  2:30.72
# Agosto     191.17  3:11.17

# %%
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili in secondi delle risoluzioni del 2026
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Tempi medi delle risoluzioni mensili
#
#           Secondi    Tempo
# Mese
# Febbraio   424.25  7:04.25
# Marzo      269.44  4:29.44
# Aprile     236.20  3:56.20
# Maggio     240.16  4:00.16
# Giugno     210.73  3:30.73
# Agosto     197.80  3:17.80

# %%
# Grafico dei tempi medi mensili delle risoluzioni 2026
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili in secondi delle risoluzioni annuali
modulo_rubik.medie_risoluzioni_annuali(df_cubo=df)
# Out:
# Tempi medi mensili in secondi delle risoluzioni annuali
#
#       Secondi    Tempo
# Anno
# 2026    300.2  5:00.20

# %%
# Grafico tempo medio risoluzioni annuali
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %% [markdown]
# ## 🔢 Analisi del numero di risoluzioni mensili e annuali

# %%
# Numero di risoluzioni mensili del 2026
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Numero di risoluzioni mensili del 2026
#
# Mese
# Marzo       24
# Febbraio    18
# Aprile       8
# Maggio       7
# Giugno       4
# Agosto       2
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2026
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)

# %%
# Numero di risoluzioni annuali
modulo_rubik.numero_risoluzioni_annuali(df_cubo=df)
# Out:
# Numero di risoluzioni annuali
#
# Anno
# 2026    63
# Name: count, dtype: int64

# %%
# Grafico numero di risoluzioni annuali
modulo_rubik.grafico_risoluz_annuali(df_cubo=df)

# %% [markdown]
# ## 📈Analisi dei tempi di risoluzione

# %% [markdown]
# ### 💯 Ultime risoluzioni (fino ad un massimo di 100)

# %%
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=100)
# Out:
# Tempo medio: 5:0.2

# %% [markdown]
# ## 📈Analisi dei tempi delle risoluzioni più recenti

# %% [markdown]
# ### 🔟 Ultime 10 risoluzioni

# %%
df.tail(10)
# Out:
#    Data completa  Anno    Mese  Giorno  Secondi    Tempo      Cubo
# 53    2026-05-13  2026  Maggio      13   217.43  3:37.43  kilominx
# 54    2026-05-09  2026  Maggio       9   225.57  3:45.57  kilominx
# 55    2026-05-20  2026  Maggio      20   273.34  4:33.34  kilominx
# 56    2026-05-20  2026  Maggio      20   260.37  4:20.37  kilominx
# 57    2026-06-06  2026  Giugno       6   227.88  3:47.88  kilominx
# 58    2026-06-14  2026  Giugno      14   278.47  4:38.47  kilominx
# 59    2026-06-14  2026  Giugno      14   150.72  2:30.72  kilominx
# 60    2026-06-14  2026  Giugno      14   185.84  3:05.84  kilominx
# 61    2026-08-22  2026  Agosto      22   191.17  3:11.17  kilominx
# 62    2026-08-22  2026  Agosto      22   204.44  3:24.44  kilominx

# %%
# Grafico delle ultime 10 risoluzioni in base alla data e ai secondi impiegati
modulo_rubik.grafico_risoluzioni_recenti(df_cubo=df)

# %%
# Grafico delle ultime 10 risoluzioni in base al numero della risoluzione e ai secondi impiegati
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=10)
# Out:
# Tempo medio: 3:41.52
