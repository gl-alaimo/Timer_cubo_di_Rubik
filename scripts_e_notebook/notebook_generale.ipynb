# %% [markdown]
# # Statistiche e grafici delle risoluzioni di tutti i Cubi di Rubik

# %% [markdown]
# <img src="../immagini/tutti_i_cubi.jpg" width="800" height="450">

# %%
# Caricamento dati delle risoluzioni dal database
import modulo_rubik
df = modulo_rubik.caricamento_dati_notebook_generale()

# %% [markdown]
# ## Dati di tutte le risoluzioni di tutti i cubi

# %%
# DataFrame contenente i dati
df
# Out:
#           Data  Secondi     Tempo      Cubo
# 0   2025-01-11   111.29   1:51.29     3x3x3
# 1   2025-01-11    78.77   1:18.77     3x3x3
# 2   2025-01-11   272.29   4:32.29     2x2x2
# 3   2025-01-11    95.09   1:35.09     3x3x3
# 4   2025-01-11   113.01   1:53.01     3x3x3
# ..         ...      ...       ...       ...
# 815 2026-08-22    20.41   0:20.41  pyraminx
# 816 2026-08-22   191.17   3:11.17  kilominx
# 817 2026-08-22   204.44   3:24.44  kilominx
# 818 2026-08-22   629.41  10:29.41     6x6x6
# 819 2026-08-22   344.67   5:44.67    mirror
#
# [820 rows x 4 columns]

# %% [markdown]
# # 📈Analisi dei tempi di risoluzione

# %%
# Grafico di tutte le risoluzioni
modulo_rubik.grafico_tutte_risoluzioni(df=df)

# %% [markdown]
# ## 🥇Record personali per tipo di cubo

# %%
# Elenco di tutti i record per tipo di cubo
modulo_rubik.mostra_tutti_record(df_cubo=df)
# Out:
#           Secondi     Tempo
# Cubo
# 2x2x2       13.01   0:13.01
# pyraminx    17.46   0:17.46
# 3x3x3       27.29   0:27.29
# 4x4x4      146.08   2:26.08
# kilominx   150.72   2:30.72
# mirror     238.89   3:58.89
# 5x5x5      309.33   5:09.33
# megaminx   334.02   5:34.02
# 6x6x6      599.60   9:59.60
# 7x7x7     1213.99  20:13.99

# %%
# Creazione grafico di tutti i record per tipo di cubo
modulo_rubik.grafico_tutti_record(df_cubo=df)

# %% [markdown]
# ## 📶Medie dei tempi di risoluzione

# %%
# Medie dei tempi di risoluzione per tipo di cubo
modulo_rubik.calcola_media_risoluzioni(df_cubo=df)
# Out:
#           Secondi     Tempo
# Cubo
# 2x2x2       43.91   0:43.91
# pyraminx    59.26   0:59.26
# 3x3x3       61.48   1:01.48
# 4x4x4      225.99   3:45.99
# kilominx   300.20   5:00.20
# mirror     443.17   7:23.17
# 5x5x5      516.69   8:36.69
# megaminx   653.38  10:53.38
# 6x6x6      928.06  15:28.06
# 7x7x7     1635.95  27:15.95

# %%
# Creazione grafico dei tempi medi di risoluzione per tipo di cubo
modulo_rubik.grafico_media_risoluzioni(df_cubo=df)

# %% [markdown]
# ## 🔢Analisi del numero di risoluzioni totali

# %%
# Numero di risoluzioni per tipo di cubo
modulo_rubik.calcola_num_risoluzioni(df_cubo=df)
# Out:
# Cubo
# 3x3x3       174
# 4x4x4       132
# 2x2x2       125
# pyraminx     89
# 5x5x5        88
# kilominx     63
# 6x6x6        59
# megaminx     45
# mirror       24
# 7x7x7        21
# Name: count, dtype: int64

# %%
# Creazione grafico delle risoluzioni per tipo di cubo
modulo_rubik.grafico_num_risoluzioni(df_cubo=df)

# %%
# Aggiunta colonna data al DataFrame
df = modulo_rubik.aggiunta_colonne_data(df_cubo=df)

# %% [markdown]
# ## 🗓️ Analisi del numero di risoluzioni mensili e annuali

# %%
# Numero di risoluzioni mensili del 2025
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2025)
# Out:
# Numero di risoluzioni mensili del 2025
#
# Mese
# Gennaio      41
# Febbraio     35
# Agosto       29
# Novembre     25
# Maggio       24
# Luglio       14
# Settembre    12
# Marzo        12
# Ottobre       6
# Aprile        2
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2025
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2025)

# %%
# Numero di risoluzioni mensili del 2026
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Numero di risoluzioni mensili del 2026
#
# Mese
# Marzo       143
# Maggio      137
# Aprile       97
# Agosto       63
# Giugno       56
# Luglio       56
# Febbraio     51
# Gennaio      17
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2026
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)

# %%
# Numero di risoluzioni annuali
modulo_rubik.numero_risoluzioni_annuali(df_cubo=df)
# Out:
# Numero di risoluzioni annuali
#
# Anno
# 2025    200
# 2026    620
# Name: count, dtype: int64

# %%
# Grafico numero di risoluzioni annuali
modulo_rubik.grafico_risoluz_annuali(df_cubo=df)
