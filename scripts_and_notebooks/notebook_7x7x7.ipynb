# %% [markdown]
# # Rubik's Cube 7x7x7 statistics and charts

# %% [markdown]
# <img src="../images/cube_7x7x7.jpg" width="400" height="450">

# %%
import rubik_module
CUBE = "7x7x7"
df = rubik_module.load_data(cube=CUBE)

# %%
# DataFrame containing solves data
df
# Out:
#     Full Date  Year  Month  Day  Seconds      Time   Cube
# 0  2026-04-17  2026  April   17  1974.72  32:54.72  7x7x7
# 1  2026-04-19  2026  April   19  2164.35  36:04.35  7x7x7
# 2  2026-05-09  2026    May    9  1630.87  27:10.87  7x7x7
# 3  2026-05-23  2026    May   23  2089.62  34:49.62  7x7x7
# 4  2026-05-23  2026    May   23  1940.69  32:20.69  7x7x7
# 5  2026-05-23  2026    May   23  2030.95  33:50.95  7x7x7
# 6  2026-05-23  2026    May   23  1994.67  33:14.67  7x7x7
# 7  2026-05-27  2026    May   27  1636.01  27:16.01  7x7x7
# 8  2026-06-02  2026   June    2  1617.22  26:57.22  7x7x7
# 9  2026-06-06  2026   June    6  1522.81  25:22.81  7x7x7
# 10 2026-06-07  2026   June    7  1443.58  24:03.58  7x7x7
# 11 2026-06-08  2026   June    8  1337.28  22:17.28  7x7x7
# 12 2026-06-17  2026   June   17  1623.90  27:03.90  7x7x7
# 13 2026-06-19  2026   June   19  1443.45  24:03.45  7x7x7
# 14 2026-07-17  2026   July   17  1613.18  26:53.18  7x7x7
# ...

# %% [markdown]
# # 📈Analysis of solve times

# %%
# Chart with data concentration of solve times
rubik_module.data_concentration_chart(df=df)

# %%
# Calculation of the correlation coefficient
rubik_module.calculate_correlation(df=df)
# Out:
# Correlation coefficient -0.8161577322056949
# This value indicates that the more solves you do, the shorter the solve time becomes

# %% [markdown]
# ## 🥇Current Record

# %%
# Personal record
rubik_module.print_record(cube=CUBE)
# Out:
# Personal best: 20 minutes and 13.99 seconds

# %% [markdown]
# ## Ranking of the 10 fastest solves 🥇🥈🥉...

# %%
# Top 10 fastest solves
rubik_module.top_solves_ranking(df_cube=df)
# Out:
# Ranking of the 10 fastest solves
#
#    Full Date  Year Month  Day  Seconds      Time  Time Difference
# 0 2026-07-26  2026  July   26  1213.99  20:13.99             0.00
# 1 2026-06-08  2026  June    8  1337.28  22:17.28           123.29
# 2 2026-07-17  2026  July   17  1371.86  22:51.86            34.58
# 3 2026-06-19  2026  June   19  1443.45  24:03.45            71.59
# 4 2026-06-07  2026  June    7  1443.58  24:03.58             0.13
# 5 2026-07-25  2026  July   25  1462.53  24:22.53            18.95
# 6 2026-07-17  2026  July   17  1489.48  24:49.48            26.95
# 7 2026-06-06  2026  June    6  1522.81  25:22.81            33.33
# 8 2026-07-17  2026  July   17  1613.18  26:53.18            90.37
# 9 2026-06-02  2026  June    2  1617.22  26:57.22             4.04

# %% [markdown]
# ## 📊 Minimum, average, and maximum solve times

# %%
# Minimum, average, and maximum solve times
rubik_module.print_record_average_maximum(df_cube=df, cube=CUBE)
# Out:
# Minimum, average, and maximum solve time:
# - Minimum time 20:13.99
#  - Average time 27:43.22
#  - Maximum time 36:4.35

# %%
# Chart of minimum, average, and maximum solve times
rubik_module.record_average_maximum_chart(df_cube=df)

# %% [markdown]
# ## 🗓️ Analysis of monthly and yearly solve times

# %%
# Monthly fastest solves in 2025
rubik_module.show_monthly_records(df_cube=df, year=2025)
# Out:
# No solves present for the year 2025.

# %%
# Chart of monthly fastest solves in 2025
rubik_module.monthly_records_chart(df_cube=df, year=2025)
# Out:
# No solves present for the year 2025.

# %%
# Monthly fastest solves in 2026
rubik_module.show_monthly_records(df_cube=df, year=2026)
# Out:
# Records established each month
#
#        Seconds      Time
# Month
# April  1974.72  32:54.72
# May    1630.87  27:10.87
# June   1337.28  22:17.28
# July   1213.99  20:13.99

# %%
# Chart of monthly fastest solves in 2026
rubik_module.monthly_records_chart(df_cube=df, year=2026)

# %%
# Monthly fastest solves of every year
rubik_module.calculate_monthly_records_all_years(df_cube=df)
# Out:
# Data not available. There are no solves registered for multiple years.

# %%
# Chart of monthly fastest solves of every year
rubik_module.monthly_records_chart_all_years(df_cube=df)
# Out:
# Chart not available. There are no solves registered for multiple years.

# %%
# Monthly average solves in 2025
rubik_module.monthly_solves_averages(df_cube=df, year=2025)
# Out:
# No solves present for the year 2025.

# %%
# Chart of monthly average solves in 2025
rubik_module.monthly_averages_chart(df_cube=df, year=2025)
# Out:
# No solves present for the year 2025.

# %%
# Monthly average solves in 2026
rubik_module.monthly_solves_averages(df_cube=df, year=2026)
# Out:
# Monthly average solve times
#
#        Seconds      Time
# Month
# April  2069.54  34:29.54
# May    1887.14  31:27.14
# June   1498.04  24:58.04
# July   1430.21  23:50.21

# %%
# Chart of monthly average solves in 2026
rubik_module.monthly_averages_chart(df_cube=df, year=2026)

# %%
# Monthly average solves of every year
rubik_module.calculate_monthly_averages_all_years(df_cube=df)
# Out:
# Data not available. There are no solves registered for multiple years.

# %%
# Chart of monthly average solves of every year
rubik_module.monthly_averages_chart_all_years(df_cube=df)
# Out:
# Chart not available. There are no solves registered for multiple years.

# %%
# Yearly fastest solves
rubik_module.annual_records(df_cube=df)
# Out:
# Yearly record solve times
#
#       Seconds      Time
# Year
# 2026  1213.99  20:13.99

# %%
# Chart of yearly fastest solves
rubik_module.annual_records_chart(df_cube=df)

# %%
# Yearly average times of yearly solves
rubik_module.yearly_solves_averages(df_cube=df)
# Out:
# Monthly average times in seconds of yearly solves
#
#       Seconds      Time
# Year
# 2026  1663.22  27:43.22

# %%
# Chart of yearly average solve times
rubik_module.yearly_averages_chart(df_cube=df)

# %% [markdown]
# ## 🔢 Analysis of monthly and yearly number of solves

# %%
# Number of monthly solves in 2025
rubik_module.monthly_solves_count(df_cube=df, year=2025)
# Out:
# No solves present for the year 2025.

# %%
# Chart of monthly solves in 2025
rubik_module.monthly_solves_chart(df_cube=df, year=2025)
# Out:
# No solves present for the year 2025.

# %%
# Number of monthly solves in 2026
rubik_module.monthly_solves_count(df_cube=df, year=2026)
# Out:
# Number of monthly solves in 2026
#
# Month
# May      6
# June     6
# July     5
# April    2
# Name: count, dtype: int64

# %%
# Chart of monthly solves in 2026
rubik_module.monthly_solves_chart(df_cube=df, year=2026)

# %%
rubik_module.calculate_monthly_solve_counts_all_years(df_cube=df)
# Out:
# Data not available. There are no solves registered for multiple years.

# %%
rubik_module.monthly_solves_chart_all_years(df_cube=df)
# Out:
# Chart not available. There are no solves registered for multiple years.

# %%
# Number of yearly solves
rubik_module.yearly_solves_count(df_cube=df)
# Out:
# Number of yearly solves
#
# Year
# 2026    19
# Name: count, dtype: int64

# %%
# Chart of yearly solves
rubik_module.yearly_solves_chart(df_cube=df)

# %% [markdown]
# ## 📈Analysis of recent solve times

# %% [markdown]
# ### 💯 Last solves (up to a maximum of 100)

# %%
rubik_module.last_total_solves_chart(df_cube=df, num_last_solves=100)
# Out:
# Average time: 27:43.22

# %% [markdown]
# ### 🔟 Last 10 solves

# %%
df.tail(10)
# Out:
#     Full Date  Year Month  Day  Seconds      Time   Cube
# 9  2026-06-06  2026  June    6  1522.81  25:22.81  7x7x7
# 10 2026-06-07  2026  June    7  1443.58  24:03.58  7x7x7
# 11 2026-06-08  2026  June    8  1337.28  22:17.28  7x7x7
# 12 2026-06-17  2026  June   17  1623.90  27:03.90  7x7x7
# 13 2026-06-19  2026  June   19  1443.45  24:03.45  7x7x7
# 14 2026-07-17  2026  July   17  1613.18  26:53.18  7x7x7
# 15 2026-07-17  2026  July   17  1371.86  22:51.86  7x7x7
# 16 2026-07-17  2026  July   17  1489.48  24:49.48  7x7x7
# 17 2026-07-26  2026  July   26  1213.99  20:13.99  7x7x7
# 18 2026-07-25  2026  July   25  1462.53  24:22.53  7x7x7

# %%
# Chart of last 10 solves by date and seconds
rubik_module.recent_solves_chart(df_cube=df)

# %%
# Chart of last 10 solves by solve number and seconds
rubik_module.last_total_solves_chart(df_cube=df, num_last_solves=10)
# Out:
# Average time: 24:12.21
