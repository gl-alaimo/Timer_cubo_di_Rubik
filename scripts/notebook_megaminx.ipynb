# %% [markdown]
# # Statistiche e grafici delle risoluzioni del<br>Megaminx

# %% [markdown]
# <img src="../immagini/megaminx.jpg" width="400" height="400">

# %%
import modulo_rubik
CUBO = "megaminx"
df = modulo_rubik.caricamento_dati(cubo=CUBO)

# %%
# DataFrame contetente i dati
df
# Out:
#    Data completa  Anno      Mese  Giorno  Secondi     Tempo      Cubo
# 0     2025-02-09  2025  Febbraio       9  1810.61  30:10.61  megaminx
# 1     2025-02-22  2025  Febbraio      22  2023.52  33:43.52  megaminx
# 2     2025-04-19  2025    Aprile      19  2632.00  43:52.00  megaminx
# 3     2026-02-25  2026  Febbraio      25   823.22  13:43.22  megaminx
# 4     2026-02-27  2026  Febbraio      27   800.78  13:20.78  megaminx
# 5     2026-03-01  2026     Marzo       1   607.73  10:07.73  megaminx
# 6     2026-03-01  2026     Marzo       1   873.80  14:33.80  megaminx
# 7     2026-03-04  2026     Marzo       4   580.80   9:40.80  megaminx
# 8     2026-03-06  2026     Marzo       6   892.92  14:52.92  megaminx
# 9     2026-03-08  2026     Marzo       8   694.82  11:34.82  megaminx
# 10    2026-03-13  2026     Marzo      13   567.54   9:27.54  megaminx
# 11    2026-03-17  2026     Marzo      17   467.31   7:47.31  megaminx
# 12    2026-03-28  2026     Marzo      28   504.55   8:24.55  megaminx
# 13    2026-03-28  2026     Marzo      28   520.49   8:40.49  megaminx
# 14    2026-03-28  2026     Marzo      28   515.23   8:35.23  megaminx
# 15    2026-04-02  2026    Aprile       2   693.87  11:33.87  megaminx
# 16    2026-04-08  2026    Aprile       8   611.08  10:11.08  megaminx
# 17    2026-04-08  2026    Aprile       8   391.48   6:31.48  megaminx
# 18    2026-04-10  2026    Aprile      10   556.93   9:16.93  megaminx
# 19    2026-04-18  2026    Aprile      18   537.55   8:57.55  megaminx
# 20    2026-04-18  2026    Aprile      18   502.87   8:22.87  megaminx
# 21    2026-04-18  2026    Aprile      18   520.73   8:40.73  megaminx
# 22    2026-04-18  2026    Aprile      18   545.46   9:05.46  megaminx
# 23    2026-04-18  2026    Aprile      18   595.66   9:55.66  megaminx
# 24    2026-04-18  2026    Aprile      18   489.89   8:09.89  megaminx
# 25    2026-05-08  2026    Maggio       8   535.20   8:55.20  megaminx
# 26    2026-05-08  2026    Maggio       8   445.38   7:25.38  megaminx
# 27    2026-05-09  2026    Maggio       9   978.91  16:18.91  megaminx
# 28    2026-05-09  2026    Maggio       9   490.03   8:10.03  megaminx
# 29    2026-05-09  2026    Maggio       9   522.76   8:42.76  megaminx
# 30    2026-05-15  2026    Maggio      15   549.51   9:09.51  megaminx
# 31    2026-05-18  2026    Maggio      18   480.82   8:00.82  megaminx
# 32    2026-05-18  2026    Maggio      18   420.09   7:00.09  megaminx
# 33    2026-06-02  2026    Giugno       2   384.70   6:24.70  megaminx
# 34    2026-06-02  2026    Giugno       2   549.75   9:09.75  megaminx

# %%
# Grafico con la concentrazione dei dati sui tempi delle risoluzioni
modulo_rubik.grafico_concentrazione_dati(df=df)

# %% [markdown]
# ## 🥇Record attuale

# %%
# Record
modulo_rubik.stampa_record(cubo=CUBO)
# Out:
# Il record attuale è di 6 minuti e 24.7 secondi

# %% [markdown]
# ## Classifica delle 10 risoluzioni più veloci 🥇🥈🥉...

# %%
modulo_rubik.classifica_migliori_soluzioni(df_cubo=df)
# Out:
# Classifica delle 10 risoluzioni più veloci
#
#   Data completa  Anno    Mese  Giorno  Secondi    Tempo  Differenza secondi
# 0    2026-06-02  2026  Giugno       2   384.70  6:24.70                0.00
# 1    2026-04-08  2026  Aprile       8   391.48  6:31.48                6.78
# 2    2026-05-18  2026  Maggio      18   420.09  7:00.09               28.61
# 3    2026-05-08  2026  Maggio       8   445.38  7:25.38               25.29
# 4    2026-03-17  2026   Marzo      17   467.31  7:47.31               21.93
# 5    2026-05-18  2026  Maggio      18   480.82  8:00.82               13.51
# 6    2026-04-18  2026  Aprile      18   489.89  8:09.89                9.07
# 7    2026-05-09  2026  Maggio       9   490.03  8:10.03                0.14
# 8    2026-04-18  2026  Aprile      18   502.87  8:22.87               12.84
# 9    2026-03-28  2026   Marzo      28   504.55  8:24.55                1.68

# %% [markdown]
# # 📈Analisi dei tempi di risoluzione

# %% [markdown]
# ## 📊 Tempo minimo, medio e massimo delle risoluzioni

# %%
# Tempo massimo medio e minimo delle risoluzioni
modulo_rubik.stampa_record_media_massimo(df_cubo=df, cubo=CUBO)
# Out:
# Tempo minimo medio e massimo delle risoluzioni:
# - Tempo minimo 6:24.7
#  - Tempo medio 11:57.66
#  - Tempo massimo 43:52.0

# %%
# Grafico tempo massimo medio e minimo delle risoluzioni
modulo_rubik.grafico_record_media_massimo(df_cubo=df)

# %% [markdown]
# ## 🗓️ Analisi dei tempi di risoluzione mensili e annuali

# %%
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2025)
# Out:
# Record stabiliti ogni mese
#
#           Secondi     Tempo
# Mese
# Febbraio  1810.61  30:10.61
# Aprile    2632.00  43:52.00

# %%
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2025)

# %%
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2026)
# Out:
# Record stabiliti ogni mese
#
#           Secondi     Tempo
# Mese
# Febbraio   800.78  13:20.78
# Marzo      467.31   7:47.31
# Aprile     391.48   6:31.48
# Maggio     420.09   7:00.09
# Giugno     384.70   6:24.70

# %%
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili in secondi delle risoluzioni del 2025
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2025)
# Out:
# Tempi medi delle risoluzioni mensili
#
#           Secondi     Tempo
# Mese
# Febbraio  1917.06  31:57.06
# Aprile    2632.00  43:52.00

# %%
# Grafico dei tempi medi mensili delle risoluzioni del 2025
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2025)

# %%
# Tempi medi mensili in secondi delle risoluzioni del 2026
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Tempi medi delle risoluzioni mensili
#
#           Secondi     Tempo
# Mese
# Febbraio   812.00  13:32.00
# Marzo      622.52  10:22.52
# Aprile     544.55   9:04.55
# Maggio     552.84   9:12.84
# Giugno     467.22   7:47.22

# %%
# Grafico dei tempi medi mensili delle risoluzioni 2026
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili in secondi delle risoluzioni annuali
modulo_rubik.medie_risoluzioni_annuali(df_cubo=df)
# Out:
# Tempi medi mensili in secondi delle risoluzioni annuali
#
#       Secondi     Tempo
# Anno
# 2025  2155.38  35:55.38
# 2026   582.87   9:42.87

# %%
# Grafico tempo medio risoluzioni annuali
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %% [markdown]
# ## 🔢 Analisi del numero di risoluzioni mensili e annuali

# %%
# Numero di risoluzioni mensili del 2025
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2025)
# Out:
# Numero di risoluzioni mensili del 2025
#
# Mese
# Febbraio    2
# Aprile      1
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2025
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2025)

# %%
# Numero di risoluzioni mensili del 2026
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Numero di risoluzioni mensili del 2026
#
# Mese
# Marzo       10
# Aprile      10
# Maggio       8
# Febbraio     2
# Giugno       2
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2026
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)

# %%
# Numero di risoluzioni annuali
modulo_rubik.numero_risoluzioni_annuali(df_cubo=df)
# Out:
# Numero di risoluzioni annuali
#
# Anno
# 2025     3
# 2026    32
# Name: count, dtype: int64

# %%
# Grafico numero di risoluzioni annuali
modulo_rubik.grafico_risoluz_annuali(df_cubo=df)

# %% [markdown]
# ## 📈Analisi dei tempi di risoluzione

# %% [markdown]
# ### 💯 Ultime risoluzioni (fino ad un massimo di 100)

# %%
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=100)
# Out:
# Tempo medio: 11:57.66

# %% [markdown]
# ## 📈Analisi dei tempi delle risoluzioni più recenti

# %% [markdown]
# ### 🔟 Ultime 10 risoluzioni

# %%
df.tail(10)
# Out:
#    Data completa  Anno    Mese  Giorno  Secondi     Tempo      Cubo
# 25    2026-05-08  2026  Maggio       8   535.20   8:55.20  megaminx
# 26    2026-05-08  2026  Maggio       8   445.38   7:25.38  megaminx
# 27    2026-05-09  2026  Maggio       9   978.91  16:18.91  megaminx
# 28    2026-05-09  2026  Maggio       9   490.03   8:10.03  megaminx
# 29    2026-05-09  2026  Maggio       9   522.76   8:42.76  megaminx
# 30    2026-05-15  2026  Maggio      15   549.51   9:09.51  megaminx
# 31    2026-05-18  2026  Maggio      18   480.82   8:00.82  megaminx
# 32    2026-05-18  2026  Maggio      18   420.09   7:00.09  megaminx
# 33    2026-06-02  2026  Giugno       2   384.70   6:24.70  megaminx
# 34    2026-06-02  2026  Giugno       2   549.75   9:09.75  megaminx

# %%
# Grafico delle ultime 10 risoluzioni in base alla data e ai secondi impiegati
modulo_rubik.grafico_risoluzioni_recenti(df_cubo=df)

# %%
# Grafico delle ultime 10 risoluzioni in base al numero della risoluzione e ai secondi impiegati
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=10)
# Out:
# Tempo medio: 8:55.71
