# %% [markdown]
# # Statistiche e grafici delle risoluzioni del<br>Megaminx

# %% [markdown]
# <img src="../immagini/megaminx.jpg" width="400" height="400">

# %%
import modulo_rubik
CUBO = "megaminx"
df = modulo_rubik.caricamento_dati(cubo=CUBO)

# %% [markdown]
# ## Ultime 10 risoluzioni

# %%
# Ultime 10 risoluzioni
df.tail(10)
# Out:
#     Data completa  Anno Mese  Giorno  Secondi     Tempo      Cubo
# 64     2025-02-22  2025  Feb      22  2023.52  33:43.52  megaminx
# 88     2025-04-19  2025  Apr      19  2632.00  43:52.00  megaminx
# 257    2026-02-25  2026  Feb      25   823.22  13:43.22  megaminx
# 264    2026-02-27  2026  Feb      27   800.78  13:20.78  megaminx
# 282    2026-03-01  2026  Mar       1   607.73  10:07.73  megaminx
# 283    2026-03-01  2026  Mar       1   873.80  14:33.80  megaminx
# 284    2026-03-04  2026  Mar       4   580.80   9:40.80  megaminx
# 289    2026-03-06  2026  Mar       6   892.92  14:52.92  megaminx
# 315    2026-03-08  2026  Mar       8   694.82  11:34.82  megaminx
# 329    2026-03-13  2026  Mar      13   567.54   9:27.54  megaminx

# %%
# Grafico delle ultime 10 risoluzioni
modulo_rubik.grafico_risoluzioni_recenti(df_cubo=df)

# %% [markdown]
# ## Record attuale🥇

# %%
# Record
modulo_rubik.stampa_record(cubo=CUBO)
# Out:
# Il record attuale è di 9 minuti e 27.54 secondi

# %% [markdown]
# ## Classifica 10 migliori risoluzioni 🥇🥈🥉...

# %%
# Classifica 10 migliori risoluzioni
df.sort_values(by="Secondi", ascending=True).head(10)
# Out:
#     Data completa  Anno Mese  Giorno  Secondi     Tempo      Cubo
# 329    2026-03-13  2026  Mar      13   567.54   9:27.54  megaminx
# 284    2026-03-04  2026  Mar       4   580.80   9:40.80  megaminx
# 282    2026-03-01  2026  Mar       1   607.73  10:07.73  megaminx
# 315    2026-03-08  2026  Mar       8   694.82  11:34.82  megaminx
# 264    2026-02-27  2026  Feb      27   800.78  13:20.78  megaminx
# 257    2026-02-25  2026  Feb      25   823.22  13:43.22  megaminx
# 283    2026-03-01  2026  Mar       1   873.80  14:33.80  megaminx
# 289    2026-03-06  2026  Mar       6   892.92  14:52.92  megaminx
# 48     2025-02-09  2025  Feb       9  1810.61  30:10.61  megaminx
# 64     2025-02-22  2025  Feb      22  2023.52  33:43.52  megaminx

# %%
# Tempo massimo medio e minimo delle risoluzioni
modulo_rubik.stampa_record_media_massimo(df_cubo=df, cubo=CUBO)
# Out:
# Tempo record 9:27.54
#  Tempo medio 18:38.89
#  Tempo massimo 43:52.0

# %%
# Grafico tempo massimo medio e minimo delle risoluzioni
modulo_rubik.grafico_record_media_massimo(df_cubo=df)

# %% [markdown]
# ## Analisi dei tempi di risoluzione mensili e annuali

# %%
# Tempi medi mensili risoluzioni del 2025
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2025)
# Out:
# Mese
# Feb    1917.06
# Apr    2632.00
# Name: Secondi, dtype: float64

# %%
# Grafico tempo medio mensile risoluzioni del 2025
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2025)

# %%
# Tempi medi mensili risoluzioni del 2026
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Mese
# Feb    812.00
# Mar    702.94
# Name: Secondi, dtype: float64

# %%
# Grafico tempo medio mensile risoluzioni del 2026
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili delle risoluzioni annuali
modulo_rubik.medie_risoluzioni_annuali(df_cubo=df)
# Out:
# Anno
# 2025    2155.38
# 2026     730.20
# Name: Secondi, dtype: float64

# %%
# Grafico tempo medio risoluzioni annuali
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %%
# Numero di risoluzioni del 2025 in base al mese
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2025)
# Out:
# Mese
# Feb    2
# Apr    1
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni del 2025 in base al mese
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2025)

# %%
# Numero di risoluzioni del 2026 in base al mese
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Mese
# Mar    6
# Feb    2
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni del 2026 in base al mese
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)
