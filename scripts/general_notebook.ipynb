# %% [markdown]
# # Statistics and charts for all Rubik's Cube solves

# %%
# Load solves data from database
import rubik_module
df = rubik_module.load_general_notebook_data()

# %% [markdown]
# ## All solves data for all cubes

# %%
# DataFrame containing the data
df
# Out:
#           Date  Seconds     Time   Cube
# 0   2025-01-11   111.29  1:51.29  3x3x3
# 1   2025-01-11    78.77  1:18.77  3x3x3
# 2   2025-01-11   272.29  4:32.29  2x2x2
# 3   2025-01-11    95.09  1:35.09  3x3x3
# 4   2025-01-11   113.01  1:53.01  3x3x3
# ..         ...      ...      ...    ...
# 770 2026-08-15    21.12  0:21.12  2x2x2
# 771 2026-08-15    18.45  0:18.45  2x2x2
# 772 2026-08-15    36.72  0:36.72  2x2x2
# 773 2026-08-15    31.65  0:31.65  2x2x2
# 774 2026-08-15    32.51  0:32.51  2x2x2
#
# [775 rows x 4 columns]

# %% [markdown]
# # 📈Analysis of solve times

# %%
# Chart of all solves
rubik_module.all_solves_chart(df)

# %% [markdown]
# ## 🥇Personal records by cube type

# %%
# List of all records by cube type
rubik_module.show_all_records(df)
# Out:
#           Seconds      Time
# Cube
# 2x2x2       13.01   0:13.01
# pyraminx    17.46   0:17.46
# 3x3x3       24.86   0:24.86
# 4x4x4      146.08   2:26.08
# kilominx   150.72   2:30.72
# mirror     238.89   3:58.89
# 5x5x5      309.33   5:09.33
# megaminx   334.02   5:34.02
# 6x6x6      599.60   9:59.60
# 7x7x7     1213.99  20:13.99

# %%
# Create chart of all records by cube type
rubik_module.all_records_chart(df)

# %% [markdown]
# ## 📶Average solve times

# %%
# Average solve times by cube type
rubik_module.calculate_solves_average(df)
# Out:
#           Seconds      Time
# Cube
# 2x2x2       45.66   0:45.66
# pyraminx    60.72   1:00.72
# 3x3x3       61.42   1:01.42
# 4x4x4      228.69   3:48.69
# kilominx   303.55   5:03.55
# mirror     447.45   7:27.45
# 5x5x5      527.80   8:47.80
# megaminx   669.78  11:09.78
# 6x6x6      956.18  15:56.18
# 7x7x7     1663.22  27:43.22

# %%
# Create chart of average solve times by cube type
rubik_module.solves_average_chart(df)

# %% [markdown]
# ## 🔢Analysis of total solve counts

# %%
# Number of solves by cube type
rubik_module.calculate_solves_count(df)
# Out:
# Cube
# 3x3x3       171
# 4x4x4       125
# 2x2x2       114
# pyraminx     85
# 5x5x5        81
# kilominx     61
# 6x6x6        54
# megaminx     42
# mirror       23
# 7x7x7        19
# Name: count, dtype: int64

# %%
# Create chart of solves by cube type
rubik_module.solves_count_chart(df)

# %%
# Add date column to DataFrame
df = rubik_module.add_date_columns(df)

# %% [markdown]
# ## 🗓️ Analysis of monthly and yearly solve counts

# %%
# Number of monthly solves in 2026
rubik_module.monthly_solves_count(df, 2026)
# Out:
# Number of monthly solves in 2026
#
# Month
# March       143
# May         137
# April        97
# June         56
# July         56
# February     51
# August       18
# January      17
# Name: count, dtype: int64

# %%
# Chart of monthly solves in 2026
rubik_module.monthly_solves_chart(df, 2026)

# %%
# Number of yearly solves
rubik_module.yearly_solves_count(df)
# Out:
# Number of yearly solves
#
# Year
# 2025    200
# 2026    575
# Name: count, dtype: int64

# %%
# Chart of yearly solves count
rubik_module.yearly_solves_chart(df)
