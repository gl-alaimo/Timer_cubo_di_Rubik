# %% [markdown]
# # Statistiche e grafici delle risoluzioni<br>Cubo di Rubik 5x5x5

# %% [markdown]
# <img src="../immagini/cubo_5x5x5.jpg" width="400" height="400">

# %%
from pandas import read_csv
import matplotlib.pyplot as plt
import modulo_rubik

df = read_csv("../database.csv", sep="\t", parse_dates=["Data"])
df = df[df["Cubo"] == "5x5x5"]
# Inserimento colonna "Tempo" con i secondi convertiti in minuti e secondi
df.insert(loc=2, column="Tempo", value=df["Secondi"].apply(modulo_rubik.conversione_secondi))
df = modulo_rubik.aggiunta_colonne_data(df)

# %% [markdown]
# ## Ultime 10 risoluzioni

# %%
# Ultime 10 risoluzioni
df.tail(10)
# Out:
#     Data completa  Anno Mese  Giorno  Secondi        Tempo   Cubo
# 167    2025-09-21  2025  Set      21   508.51   (8, 28.51)  5x5x5
# 168    2025-09-28  2025  Set      28   643.00   (10, 43.0)  5x5x5
# 175    2025-11-02  2025  Nov       2   821.27  (13, 41.27)  5x5x5
# 208    2026-01-25  2026  Gen      25   560.18   (9, 20.18)  5x5x5
# 209    2026-01-28  2026  Gen      28   548.75    (9, 8.75)  5x5x5
# 210    2026-01-28  2026  Gen      28   469.48   (7, 49.48)  5x5x5
# 217    2026-02-01  2026  Feb       1   473.78   (7, 53.78)  5x5x5
# 218    2026-02-01  2026  Feb       1   671.45  (11, 11.45)  5x5x5
# 240    2026-02-19  2026  Feb      19   775.82  (12, 55.82)  5x5x5
# 242    2026-02-20  2026  Feb      20   572.90    (9, 32.9)  5x5x5

# %%
# Grafico delle ultime 10 risoluzioni
modulo_rubik.grafico_risoluzioni_recenti(df=df)

# %% [markdown]
# ## Record attuale🥇

# %%
# Record
minuti, secondi = modulo_rubik.conversione_secondi((modulo_rubik.ricerca_record(cubo="5x5x5")))
print(f"Il record attuale è di {minuti} minuti e {secondi} secondi")
# Out:
# Il record attuale è di 7 minuti e 49.48 secondi

# %% [markdown]
# ## Classifica 10 migliori risoluzioni 🥇🥈🥉...

# %%
# Classifica 10 migliori risoluzioni
df.sort_values(by="Secondi", ascending=True).head(10)
# Out:
#     Data completa  Anno Mese  Giorno  Secondi       Tempo   Cubo
# 210    2026-01-28  2026  Gen      28   469.48  (7, 49.48)  5x5x5
# 217    2026-02-01  2026  Feb       1   473.78  (7, 53.78)  5x5x5
# 156    2025-08-30  2025  Ago      30   479.65  (7, 59.65)  5x5x5
# 163    2025-09-21  2025  Set      21   505.49  (8, 25.49)  5x5x5
# 167    2025-09-21  2025  Set      21   508.51  (8, 28.51)  5x5x5
# 164    2025-09-21  2025  Set      21   518.76  (8, 38.76)  5x5x5
# 209    2026-01-28  2026  Gen      28   548.75   (9, 8.75)  5x5x5
# 208    2026-01-25  2026  Gen      25   560.18  (9, 20.18)  5x5x5
# 166    2025-09-21  2025  Set      21   563.14  (9, 23.14)  5x5x5
# 135    2025-08-10  2025  Ago      10   563.77  (9, 23.77)  5x5x5

# %% [markdown]
# ## Tempo medio mensile delle risoluzioni

# %%
# Tempo medio mensile risoluzioni
df.groupby(by=["Mese"], sort=False)["Secondi"].mean().round(2)
# Out:
# Mese
# Gen    683.80
# Feb    741.28
# Mar    652.34
# Apr    934.00
# Lug    802.79
# Ago    645.25
# Set    604.65
# Nov    821.27
# Name: Secondi, dtype: float64

# %%
# Grafico tempo medio mensile risoluzioni
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2025)

# %%
# Grafico tempo medio mensile risoluzioni
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %%
modulo_rubik.grafico_record_media_massimo(df)

# %%
# Numero di risoluzioni del 2025 in base al mese
df[df["Anno"]==2025]["Mese"].value_counts()
# Out:
# Mese
# Set    7
# Ago    6
# Feb    3
# Lug    3
# Gen    2
# Mar    1
# Apr    1
# Nov    1
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni del 2025 in base al mese
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2025)

# %%
# Numero di risoluzioni del 2026 in base al mese
df[df["Anno"]==2026]["Mese"].value_counts()
# Out:
# Mese
# Feb    4
# Gen    3
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni del 2026 in base al mese
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)
