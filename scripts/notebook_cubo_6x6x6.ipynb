# %% [markdown]
# # Statistiche e grafici delle risoluzioni<br>Cubo di Rubik 6x6x6

# %% [markdown]
# <img src="../immagini/cubo_6x6x6.jpg" width="400" height="400">

# %%
import modulo_rubik
CUBO = "6x6x6"
df = modulo_rubik.caricamento_dati(cubo=CUBO)

# %% [markdown]
# ## 📶 Ultime 10 risoluzioni

# %%
# Ultime 10 risoluzioni
df.tail(10)
# Out:
#    Data completa  Anno    Mese  Giorno  Secondi     Tempo   Cubo
# 5     2026-03-18  2026   Marzo      18  1162.19  19:22.19  6x6x6
# 6     2026-03-20  2026   Marzo      20  1157.87  19:17.87  6x6x6
# 7     2026-03-20  2026   Marzo      20   864.46  14:24.46  6x6x6
# 8     2026-03-21  2026   Marzo      21   969.80  16:09.80  6x6x6
# 9     2026-03-24  2026   Marzo      24   952.98  15:52.98  6x6x6
# 10    2026-03-24  2026   Marzo      24  1051.20  17:31.20  6x6x6
# 11    2026-03-24  2026   Marzo      24  1055.38  17:35.38  6x6x6
# 12    2026-04-01  2026  Aprile       1  1400.09  23:20.09  6x6x6
# 13    2026-04-01  2026  Aprile       1  1109.03  18:29.03  6x6x6
# 14    2026-04-01  2026  Aprile       1   811.06  13:31.06  6x6x6

# %%
# Grafico delle ultime 10 risoluzioni
modulo_rubik.grafico_risoluzioni_recenti(df_cubo=df)

# %% [markdown]
# ## 🥇Record attuale

# %%
# Record
modulo_rubik.stampa_record(cubo=CUBO)
# Out:
# Il record attuale è di 13 minuti e 31.06 secondi

# %% [markdown]
# ## Classifica 10 migliori risoluzioni 🥇🥈🥉...

# %%
# Classifica 10 migliori risoluzioni
df.sort_values(by="Secondi", ascending=True).head(10)
# Out:
#    Data completa  Anno    Mese  Giorno  Secondi     Tempo   Cubo
# 14    2026-04-01  2026  Aprile       1   811.06  13:31.06  6x6x6
# 7     2026-03-20  2026   Marzo      20   864.46  14:24.46  6x6x6
# 9     2026-03-24  2026   Marzo      24   952.98  15:52.98  6x6x6
# 8     2026-03-21  2026   Marzo      21   969.80  16:09.80  6x6x6
# 3     2026-03-14  2026   Marzo      14   970.05  16:10.05  6x6x6
# 10    2026-03-24  2026   Marzo      24  1051.20  17:31.20  6x6x6
# 11    2026-03-24  2026   Marzo      24  1055.38  17:35.38  6x6x6
# 13    2026-04-01  2026  Aprile       1  1109.03  18:29.03  6x6x6
# 6     2026-03-20  2026   Marzo      20  1157.87  19:17.87  6x6x6
# 5     2026-03-18  2026   Marzo      18  1162.19  19:22.19  6x6x6

# %% [markdown]
# ## 📊 Tempo minimo, medio e massimo delle risoluzioni

# %%
# Tempo massimo medio e minimo delle risoluzioni
modulo_rubik.stampa_record_media_massimo(df_cubo=df, cubo=CUBO)
# Out:
# Tempo minimo medio e massimo delle risoluzioni:
# - Tempo minimo 13:31.06
#  - Tempo medio 21:4.94
#  - Tempo massimo 36:19.69

# %%
# Grafico tempo massimo medio e minimo delle risoluzioni
modulo_rubik.grafico_record_media_massimo(df_cubo=df)

# %% [markdown]
# ## 🗓️ Analisi dei tempi di risoluzione mensili e annuali

# %%
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2026)
# Out:
# Record stabiliti ogni mese
#
# Mese
# Marzo     864.46
# Aprile    811.06
# Name: Secondi, dtype: float64

# %%
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2026)

# %%
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2026)
# Out:
# Record stabiliti ogni mese
#
# Mese
# Marzo     864.46
# Aprile    811.06
# Name: Secondi, dtype: float64

# %%
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili risoluzioni del 2026
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Tempi medi delle risoluzioni mensili
#
# Mese
# Marzo     1304.49
# Aprile    1106.73
# Name: Secondi, dtype: float64

# %%
# Grafico tempo medio mensile risoluzioni del 2026
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili delle risoluzioni annuali
modulo_rubik.medie_risoluzioni_annuali(df_cubo=df)
# Out:
# Tempi medi mensili in secondi delle risoluzioni annuali
#
# Anno
# 2026    1264.94
# Name: Secondi, dtype: float64

# %%
# Grafico tempo medio risoluzioni annuali
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %% [markdown]
# ## 🔢 Analisi del numero di risoluzione mensili

# %%
# Numero di risoluzioni del 2026 in base al mese
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Numero di risoluzioni mensili del 2026
#
# Mese
# Marzo     12
# Aprile     3
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni del 2026 in base al mese
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)
