# %% [markdown]
# # Rubik's Cube 6x6x6 statistics and charts

# %% [markdown]
# <img src="../immagini/cubo_6x6x6.jpg" width="400" height="400">

# %%
import rubik_module
CUBE = "6x6x6"
df = rubik_module.load_data(cube=CUBE)

# %%
# DataFrame containing solves data
df
# Out:
#     Full Date  Year  Month  Day  Seconds      Time   Cube
# 0  2026-03-10  2026  March   10  2179.69  36:19.69  6x6x6
# 1  2026-03-12  2026  March   12  1909.34  31:49.34  6x6x6
# 2  2026-03-13  2026  March   13  2064.87  34:24.87  6x6x6
# 3  2026-03-14  2026  March   14   970.05  16:10.05  6x6x6
# 4  2026-03-17  2026  March   17  1316.09  21:56.09  6x6x6
# 5  2026-03-18  2026  March   18  1162.19  19:22.19  6x6x6
# 6  2026-03-20  2026  March   20  1157.87  19:17.87  6x6x6
# 7  2026-03-20  2026  March   20   864.46  14:24.46  6x6x6
# 8  2026-03-21  2026  March   21   969.80  16:09.80  6x6x6
# 9  2026-03-24  2026  March   24   952.98  15:52.98  6x6x6
# 10 2026-03-24  2026  March   24  1051.20  17:31.20  6x6x6
# 11 2026-03-24  2026  March   24  1055.38  17:35.38  6x6x6
# 12 2026-04-01  2026  April    1  1400.09  23:20.09  6x6x6
# 13 2026-04-01  2026  April    1  1109.03  18:29.03  6x6x6
# 14 2026-04-01  2026  April    1   811.06  13:31.06  6x6x6
# 15 2026-03-04  2026  March    4   986.23  16:26.23  6x6x6
# 16 2026-03-04  2026  March    4  1037.35  17:17.35  6x6x6
# 17 2026-04-06  2026  April    6  1032.02  17:12.02  6x6x6
# 18 2026-04-06  2026  April    6   927.55  15:27.55  6x6x6
# 19 2026-04-06  2026  April    6   950.78  15:50.78  6x6x6
# 20 2026-04-06  2026  April    6   913.09  15:13.09  6x6x6
# 21 2026-04-06  2026  April    6   789.78  13:09.78  6x6x6
# 22 2026-04-10  2026  April   10   942.37  15:42.37  6x6x6
# 23 2026-04-17  2026  April   17   966.52  16:06.52  6x6x6
# 24 2026-04-18  2026  April   18  1096.21  18:16.21  6x6x6
# 25 2026-04-19  2026  April   19   776.52  12:56.52  6x6x6
# 26 2026-05-05  2026    May    5   901.31  15:01.31  6x6x6
# 27 2026-05-10  2026    May   10   994.35  16:34.35  6x6x6
# 28 2026-05-10  2026    May   10   691.74  11:31.74  6x6x6
# 29 2026-05-09  2026    May    9   758.26  12:38.26  6x6x6
# 30 2026-05-15  2026    May   15   930.14  15:30.14  6x6x6
# 31 2026-05-22  2026    May   22   908.40  15:08.40  6x6x6
# 32 2026-05-27  2026    May   27   897.25  14:57.25  6x6x6
# 33 2026-05-30  2026    May   30   929.39  15:29.39  6x6x6

# %% [markdown]
# # 📈Analysis of solve times

# %%
# Chart with data concentration of solve times
rubik_module.data_concentration_chart(df=df)

# %%
# Calculation of the correlation coefficient
rubik_module.calculate_correlation(df=df)
# Out:
# Correlation coefficient -0.6409335352894031
# This value indicates that the more solves you do, the shorter the solve time becomes

# %% [markdown]
# ## 🥇Current Record

# %%
# Personal record
rubik_module.print_record(cube=CUBE)
# Out:
# Personal best: 11 minutes and 31.74 seconds

# %% [markdown]
# ## Ranking of the 10 fastest solves 🥇🥈🥉...

# %%
# Top 10 fastest solves
rubik_module.top_solves_ranking(df_cube=df)
# Out:
# Ranking of the 10 fastest solves
#
#    Full Date  Year  Month  Day  Seconds      Time  Time Difference
# 0 2026-05-10  2026    May   10   691.74  11:31.74             0.00
# 1 2026-05-09  2026    May    9   758.26  12:38.26            66.52
# 2 2026-04-19  2026  April   19   776.52  12:56.52            18.26
# 3 2026-04-06  2026  April    6   789.78  13:09.78            13.26
# 4 2026-04-01  2026  April    1   811.06  13:31.06            21.28
# 5 2026-03-20  2026  March   20   864.46  14:24.46            53.40
# 6 2026-05-27  2026    May   27   897.25  14:57.25            32.79
# 7 2026-05-05  2026    May    5   901.31  15:01.31             4.06
# 8 2026-05-22  2026    May   22   908.40  15:08.40             7.09
# 9 2026-04-06  2026  April    6   913.09  15:13.09             4.69

# %% [markdown]
# ## 📊 Minimum, average, and maximum solve times

# %%
# Minimum, average, and maximum solve times
rubik_module.print_record_average_maximum(df_cube=df, cube=CUBE)
# Out:
# Minimum, average, and maximum solve time:
# - Minimum time 11:31.74
#  - Average time 17:50.69
#  - Maximum time 36:19.69

# %%
# Chart of minimum, average, and maximum solve times
rubik_module.record_average_maximum_chart(df_cube=df)

# %% [markdown]
# ## 🗓️ Analysis of monthly and yearly solve times

# %%
# Monthly fastest solves in 2026
rubik_module.show_monthly_records(df_cube=df, year=2026)
# Out:
# Records established each month
#
#        Seconds      Time
# Month
# March   864.46  14:24.46
# April   776.52  12:56.52
# May     691.74  11:31.74

# %%
# Chart of monthly fastest solves in 2026
rubik_module.monthly_records_chart(df_cube=df, year=2026)

# %%
# Monthly average solves in 2026
rubik_module.monthly_solves_averages(df_cube=df, year=2026)
# Out:
# Monthly average solve times
#
#        Seconds      Time
# Month
# March  1262.68  21:02.68
# April   976.25  16:16.25
# May     876.36  14:36.36

# %%
# Chart of monthly average solves in 2026
rubik_module.monthly_averages_chart(df_cube=df, year=2026)

# %%
# Monthly average times of yearly solves
rubik_module.yearly_solves_averages(df_cube=df)
# Out:
# Monthly average times in seconds of yearly solves
#
#       Seconds      Time
# Year
# 2026  1070.69  17:50.69

# %%
# Chart of yearly average solve times
rubik_module.yearly_averages_chart(df_cube=df)

# %% [markdown]
# ## 🔢 Analysis of monthly and yearly number of solves

# %%
# Number of monthly solves in 2026
rubik_module.monthly_solves_count(df_cube=df, year=2026)
# Out:
# Number of monthly solves in 2026
#
# Month
# March    14
# April    12
# May       8
# Name: count, dtype: int64

# %%
# Chart of monthly solves in 2026
rubik_module.monthly_solves_chart(df_cube=df, year=2026)

# %%
# Number of yearly solves
rubik_module.yearly_solves_count(df_cube=df)
# Out:
# Number of yearly solves
#
# Year
# 2026    34
# Name: count, dtype: int64

# %%
# Chart of yearly solves
rubik_module.yearly_solves_chart(df_cube=df)

# %% [markdown]
# ## 📈Analysis of recent solve times

# %% [markdown]
# ### 💯 Last solves (up to a maximum of 100)

# %%
rubik_module.last_total_solves_chart(df_cube=df, num_last_solves=100)
# Out:
# Average time: 17:50.69

# %% [markdown]
# ### 🔟 Last 10 solves

# %%
df.tail(10)
# Out:
#     Full Date  Year  Month  Day  Seconds      Time   Cube
# 24 2026-04-18  2026  April   18  1096.21  18:16.21  6x6x6
# 25 2026-04-19  2026  April   19   776.52  12:56.52  6x6x6
# 26 2026-05-05  2026    May    5   901.31  15:01.31  6x6x6
# 27 2026-05-10  2026    May   10   994.35  16:34.35  6x6x6
# 28 2026-05-10  2026    May   10   691.74  11:31.74  6x6x6
# 29 2026-05-09  2026    May    9   758.26  12:38.26  6x6x6
# 30 2026-05-15  2026    May   15   930.14  15:30.14  6x6x6
# 31 2026-05-22  2026    May   22   908.40  15:08.40  6x6x6
# 32 2026-05-27  2026    May   27   897.25  14:57.25  6x6x6
# 33 2026-05-30  2026    May   30   929.39  15:29.39  6x6x6

# %%
# Chart of last 10 solves by date and seconds
rubik_module.recent_solves_chart(df_cube=df)

# %%
# Chart of last 10 solves by solve number and seconds
rubik_module.last_total_solves_chart(df_cube=df, num_last_solves=10)
# Out:
# Average time: 14:48.36
