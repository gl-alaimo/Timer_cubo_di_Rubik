# %% [markdown]
# # Statistiche e grafici delle risoluzioni del<br>Kilominx

# %% [markdown]
# <img src="../immagini/kilominx.jpg" width="400" height="450">

# %%
import modulo_rubik
CUBO = "kilominx"
df = modulo_rubik.caricamento_dati(cubo=CUBO)

# %%
# DataFrame contetente i dati
df
# Out:
#    Data completa  Anno      Mese  Giorno  Secondi     Tempo      Cubo
# 0     2026-02-17  2026  Febbraio      17   746.26  12:26.26  kilominx
# 1     2026-02-17  2026  Febbraio      17   640.63  10:40.63  kilominx
# 2     2026-02-17  2026  Febbraio      17   442.95   7:22.95  kilominx
# 3     2026-02-18  2026  Febbraio      18   542.82   9:02.82  kilominx
# 4     2026-02-18  2026  Febbraio      18   396.86   6:36.86  kilominx
# 5     2026-02-18  2026  Febbraio      18   476.23   7:56.23  kilominx
# 6     2026-02-20  2026  Febbraio      20   375.00   6:15.00  kilominx
# 7     2026-02-20  2026  Febbraio      20   453.28   7:33.28  kilominx
# 8     2026-02-20  2026  Febbraio      20   319.94   5:19.94  kilominx
# 9     2026-02-20  2026  Febbraio      20   504.70   8:24.70  kilominx
# 10    2026-02-21  2026  Febbraio      21   532.30   8:52.30  kilominx
# 11    2026-02-21  2026  Febbraio      21   305.67   5:05.67  kilominx
# 12    2026-02-21  2026  Febbraio      21   329.05   5:29.05  kilominx
# 13    2026-02-22  2026  Febbraio      22   320.07   5:20.07  kilominx
# 14    2026-02-22  2026  Febbraio      22   407.63   6:47.63  kilominx
# 15    2026-02-25  2026  Febbraio      25   287.22   4:47.22  kilominx
# 16    2026-02-25  2026  Febbraio      25   323.75   5:23.75  kilominx
# 17    2026-02-27  2026  Febbraio      27   232.15   3:52.15  kilominx
# 18    2026-03-01  2026     Marzo       1   286.78   4:46.78  kilominx
# 19    2026-03-01  2026     Marzo       1   274.55   4:34.55  kilominx
# 20    2026-03-04  2026     Marzo       4   307.18   5:07.18  kilominx
# 21    2026-03-08  2026     Marzo       8   322.74   5:22.74  kilominx
# 22    2026-03-12  2026     Marzo      12   312.45   5:12.45  kilominx
# 23    2026-03-18  2026     Marzo      18   220.07   3:40.07  kilominx
# 24    2026-03-18  2026     Marzo      18   232.00   3:52.00  kilominx
# 25    2026-03-20  2026     Marzo      20   224.39   3:44.39  kilominx
# 26    2026-03-20  2026     Marzo      20   239.51   3:59.51  kilominx
# 27    2026-03-21  2026     Marzo      21   307.57   5:07.57  kilominx
# 28    2026-03-21  2026     Marzo      21   231.83   3:51.83  kilominx
# 29    2026-03-26  2026     Marzo      26   551.60   9:11.60  kilominx
# 30    2026-03-26  2026     Marzo      26   280.77   4:40.77  kilominx
# 31    2026-03-28  2026     Marzo      28   269.48   4:29.48  kilominx
# 32    2026-03-28  2026     Marzo      28   252.80   4:12.80  kilominx
# 33    2026-03-28  2026     Marzo      28   169.19   2:49.19  kilominx
# 34    2026-03-31  2026     Marzo      31   235.32   3:55.32  kilominx
# 35    2026-03-31  2026     Marzo      31   399.66   6:39.66  kilominx
# 36    2026-03-31  2026     Marzo      31   294.84   4:54.84  kilominx
# 37    2026-03-31  2026     Marzo      31   240.57   4:00.57  kilominx
# 38    2026-04-01  2026    Aprile       1   266.09   4:26.09  kilominx
# 39    2026-04-01  2026    Aprile       1   339.53   5:39.53  kilominx
# 40    2026-03-03  2026     Marzo       3   169.51   2:49.51  kilominx
# 41    2026-03-03  2026     Marzo       3   257.34   4:17.34  kilominx
# 42    2026-03-03  2026     Marzo       3   189.89   3:09.89  kilominx
# 43    2026-03-03  2026     Marzo       3   196.57   3:16.57  kilominx
# 44    2026-04-06  2026    Aprile       6   234.35   3:54.35  kilominx
# 45    2026-04-06  2026    Aprile       6   168.89   2:48.89  kilominx
# 46    2026-04-06  2026    Aprile       6   222.16   3:42.16  kilominx
# 47    2026-04-14  2026    Aprile      14   261.26   4:21.26  kilominx
# 48    2026-04-14  2026    Aprile      14   166.06   2:46.06  kilominx
# 49    2026-04-17  2026    Aprile      17   231.22   3:51.22  kilominx
# 50    2026-05-08  2026    Maggio       8   195.33   3:15.33  kilominx
# 51    2026-05-08  2026    Maggio       8   276.84   4:36.84  kilominx
# 52    2026-05-08  2026    Maggio       8   232.21   3:52.21  kilominx
# 53    2026-05-13  2026    Maggio      13   217.43   3:37.43  kilominx
# 54    2026-05-09  2026    Maggio       9   225.57   3:45.57  kilominx
# 55    2026-05-20  2026    Maggio      20   273.34   4:33.34  kilominx
# 56    2026-05-20  2026    Maggio      20   260.37   4:20.37  kilominx

# %%
# Grafico con la concentrazione dei dati sui tempi delle risoluzioni
modulo_rubik.grafico_concentrazione_dati(df=df)

# %% [markdown]
# ## 🥇Record attuale

# %%
# Record
modulo_rubik.stampa_record(cubo=CUBO)
# Out:
# Il record attuale è di 2 minuti e 46.06 secondi

# %% [markdown]
# ## Classifica delle 10 risoluzioni più veloci 🥇🥈🥉...

# %%
modulo_rubik.classifica_migliori_soluzioni(df_cubo=df)
# Out:
# Classifica delle 10 risoluzioni più veloci
#
#   Data completa  Anno    Mese  Giorno  Secondi    Tempo  Differenza secondi
# 0    2026-04-14  2026  Aprile      14   166.06  2:46.06                0.00
# 1    2026-04-06  2026  Aprile       6   168.89  2:48.89                2.83
# 2    2026-03-28  2026   Marzo      28   169.19  2:49.19                0.30
# 3    2026-03-03  2026   Marzo       3   169.51  2:49.51                0.32
# 4    2026-03-03  2026   Marzo       3   189.89  3:09.89               20.38
# 5    2026-05-08  2026  Maggio       8   195.33  3:15.33                5.44
# 6    2026-03-03  2026   Marzo       3   196.57  3:16.57                1.24
# 7    2026-05-13  2026  Maggio      13   217.43  3:37.43               20.86
# 8    2026-03-18  2026   Marzo      18   220.07  3:40.07                2.64
# 9    2026-04-06  2026  Aprile       6   222.16  3:42.16                2.09

# %% [markdown]
# # 📈Analisi dei tempi di risoluzione

# %% [markdown]
# ## 📊 Tempo minimo, medio e massimo delle risoluzioni

# %%
# Tempo massimo medio e minimo delle risoluzioni
modulo_rubik.stampa_record_media_massimo(df_cubo=df, cubo=CUBO)
# Out:
# Tempo minimo medio e massimo delle risoluzioni:
# - Tempo minimo 2:46.06
#  - Tempo medio 5:10.07
#  - Tempo massimo 12:26.26

# %%
# Grafico tempo massimo medio e minimo delle risoluzioni
modulo_rubik.grafico_record_media_massimo(df_cubo=df)

# %% [markdown]
# ## 🗓️ Analisi dei tempi di risoluzione mensili e annuali

# %%
modulo_rubik.mostra_record_mensili(df_cubo=df, anno=2026)
# Out:
# Record stabiliti ogni mese
#
#           Secondi    Tempo
# Mese
# Febbraio   232.15  3:52.15
# Marzo      169.19  2:49.19
# Aprile     166.06  2:46.06
# Maggio     195.33  3:15.33

# %%
modulo_rubik.grafico_record_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili in secondi delle risoluzioni del 2026
modulo_rubik.medie_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Tempi medi delle risoluzioni mensili
#
#           Secondi    Tempo
# Mese
# Febbraio   424.25  7:04.25
# Marzo      269.44  4:29.44
# Aprile     236.20  3:56.20
# Maggio     240.16  4:00.16

# %%
# Grafico dei tempi medi mensili delle risoluzioni 2026
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
# Tempi medi mensili in secondi delle risoluzioni annuali
modulo_rubik.medie_risoluzioni_annuali(df_cubo=df)
# Out:
# Tempi medi mensili in secondi delle risoluzioni annuali
#
#       Secondi    Tempo
# Anno
# 2026   310.07  5:10.07

# %%
# Grafico tempo medio risoluzioni annuali
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %% [markdown]
# ## 🔢 Analisi del numero di risoluzioni mensili e annuali

# %%
# Numero di risoluzioni mensili del 2026
modulo_rubik.numero_risoluzioni_mensili(df_cubo=df, anno=2026)
# Out:
# Numero di risoluzioni mensili del 2026
#
# Mese
# Marzo       24
# Febbraio    18
# Aprile       8
# Maggio       7
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni mensili del 2026
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)

# %%
# Numero di risoluzioni annuali
modulo_rubik.numero_risoluzioni_annuali(df_cubo=df)
# Out:
# Numero di risoluzioni annuali
#
# Anno
# 2026    57
# Name: count, dtype: int64

# %%
# Grafico numero di risoluzioni annuali
modulo_rubik.grafico_risoluz_annuali(df_cubo=df)

# %% [markdown]
# ## 📈Analisi dei tempi di risoluzione

# %% [markdown]
# ### 💯 Ultime risoluzioni (fino ad un massimo di 100)

# %%
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=100)
# Out:
# Tempo medio: 5:10.07

# %% [markdown]
# ## 📈Analisi dei tempi delle risoluzioni più recenti

# %% [markdown]
# ### 🔟 Ultime 10 risoluzioni

# %%
df.tail(10)
# Out:
#    Data completa  Anno    Mese  Giorno  Secondi    Tempo      Cubo
# 47    2026-04-14  2026  Aprile      14   261.26  4:21.26  kilominx
# 48    2026-04-14  2026  Aprile      14   166.06  2:46.06  kilominx
# 49    2026-04-17  2026  Aprile      17   231.22  3:51.22  kilominx
# 50    2026-05-08  2026  Maggio       8   195.33  3:15.33  kilominx
# 51    2026-05-08  2026  Maggio       8   276.84  4:36.84  kilominx
# 52    2026-05-08  2026  Maggio       8   232.21  3:52.21  kilominx
# 53    2026-05-13  2026  Maggio      13   217.43  3:37.43  kilominx
# 54    2026-05-09  2026  Maggio       9   225.57  3:45.57  kilominx
# 55    2026-05-20  2026  Maggio      20   273.34  4:33.34  kilominx
# 56    2026-05-20  2026  Maggio      20   260.37  4:20.37  kilominx

# %%
# Grafico delle ultime 10 risoluzioni in base alla data e ai secondi impiegati
modulo_rubik.grafico_risoluzioni_recenti(df_cubo=df)

# %%
# Grafico delle ultime 10 risoluzioni in base al numero della risoluzione e ai secondi impiegati
modulo_rubik.grafico_ultime_tot_risoluzioni(df_cubo=df, num_ultime_risoluzioni=10)
# Out:
# Tempo medio: 3:53.96
