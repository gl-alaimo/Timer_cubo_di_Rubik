# %% [markdown]
# # Statistiche e grafici delle risoluzioni<br>Cubo di Rubik 3x3x3

# %% [markdown]
# <img src="../immagini/cubo_3x3x3.jpg" width="400" height="400">

# %%
from pandas import read_csv
import matplotlib.pyplot as plt
import modulo_rubik

df = read_csv("../database.csv", sep="\t", parse_dates=["Data"])
df = df[df["Cubo"] == "3x3x3"]
# Inserimento colonna "Tempo" con i secondi convertiti in minuti e secondi
df.insert(loc=2, column="Tempo", value=df["Secondi"].apply(modulo_rubik.conversione_secondi))
df = modulo_rubik.aggiunta_colonne_data(df)

# %% [markdown]
# ## Ultime 10 risoluzioni

# %%
# Ultime 10 risoluzioni
df.tail(10)
# Out:
#     Data completa  Anno Mese  Giorno  Secondi       Tempo   Cubo
# 195    2025-11-14  2025  Nov      14    67.76   (1, 7.76)  3x3x3
# 196    2025-11-14  2025  Nov      14    53.72  (0, 53.72)  3x3x3
# 197    2025-11-14  2025  Nov      14    50.31  (0, 50.31)  3x3x3
# 204    2026-01-10  2026  Gen      10    65.97   (1, 5.97)  3x3x3
# 205    2026-01-10  2026  Gen      10    40.44  (0, 40.44)  3x3x3
# 206    2026-01-10  2026  Gen      10    53.02  (0, 53.02)  3x3x3
# 238    2026-02-19  2026  Feb      19    63.00    (1, 3.0)  3x3x3
# 247    2026-02-21  2026  Feb      21    51.66  (0, 51.66)  3x3x3
# 248    2026-02-21  2026  Feb      21    55.81  (0, 55.81)  3x3x3
# 249    2026-02-21  2026  Feb      21    49.44  (0, 49.44)  3x3x3

# %%
# Grafico delle ultime 10 risoluzioni
modulo_rubik.grafico_risoluzioni_recenti(df=df)

# %% [markdown]
# ## Record attuale🥇

# %%
# Record
minuti, secondi = modulo_rubik.conversione_secondi((modulo_rubik.ricerca_record(cubo="3x3x3")))
print(f"Il record attuale è di {minuti} minuti e {secondi} secondi")
# Out:
# Il record attuale è di 0 minuti e 40.44 secondi

# %% [markdown]
# ## Classifica 10 migliori risoluzioni 🥇🥈🥉...

# %%
# Classifica 10 migliori risoluzioni
df.sort_values(by="Secondi", ascending=True).head(10)
# Out:
#     Data completa  Anno Mese  Giorno  Secondi       Tempo   Cubo
# 205    2026-01-10  2026  Gen      10    40.44  (0, 40.44)  3x3x3
# 94     2025-05-03  2025  Mag       3    44.56  (0, 44.56)  3x3x3
# 105    2025-05-28  2025  Mag      28    44.56  (0, 44.56)  3x3x3
# 186    2025-11-11  2025  Nov      11    46.41  (0, 46.41)  3x3x3
# 249    2026-02-21  2026  Feb      21    49.44  (0, 49.44)  3x3x3
# 197    2025-11-14  2025  Nov      14    50.31  (0, 50.31)  3x3x3
# 247    2026-02-21  2026  Feb      21    51.66  (0, 51.66)  3x3x3
# 187    2025-11-11  2025  Nov      11    52.46  (0, 52.46)  3x3x3
# 206    2026-01-10  2026  Gen      10    53.02  (0, 53.02)  3x3x3
# 196    2025-11-14  2025  Nov      14    53.72  (0, 53.72)  3x3x3

# %% [markdown]
# ## Tempo medio mensile delle risoluzioni

# %%
# Tempo medio mensile risoluzioni
df.groupby(by=["Mese"], sort=False)["Secondi"].mean().round(2)
# Out:
# Mese
# Gen    88.21
# Feb    67.38
# Mar    62.34
# Mag    64.13
# Lug    74.78
# Ago    85.53
# Ott    69.29
# Nov    56.88
# Name: Secondi, dtype: float64

# %%
# Grafico tempo medio mensile risoluzioni
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2025)

# %%
# Grafico tempo medio mensile risoluzioni
modulo_rubik.grafico_medie_mensili(df_cubo=df, anno=2026)

# %%
modulo_rubik.grafico_medie_annuali(df_cubo=df)

# %%
modulo_rubik.grafico_record_media_massimo(df)

# %%
# Numero di risoluzioni del 2025 in base al mese
df[df["Anno"]==2025]["Mese"].value_counts()
# Out:
# Mese
# Gen    16
# Feb    16
# Mag    13
# Nov    10
# Mar     5
# Lug     4
# Ott     3
# Ago     1
# Name: count, dtype: int64

# %%
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2025)

# %%
# Numero di risoluzioni del 2026 in base al mese
df[df["Anno"]==2026]["Mese"].value_counts()
# Out:
# Mese
# Feb    4
# Gen    3
# Name: count, dtype: int64

# %%
# Grafico del numero di risoluzioni del 2026 in base al mese
modulo_rubik.grafico_risoluz_mensile(df_cubo=df, anno=2026)
